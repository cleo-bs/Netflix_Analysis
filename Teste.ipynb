# %% [markdown]
# <a href="https://colab.research.google.com/github/cleo-bs/Netflix_Analysis/blob/main/Teste.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv(r'netflix.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8787 entries, 0 to 8789
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8787 non-null   object
#  1   type          8787 non-null   object
#  2   title         8787 non-null   object
#  3   country       8787 non-null   object
#  4   date_added    8773 non-null   datetime64[ns]
#  5   release_year  8787 non-null   datetime64[ns]
#  6   rating        8787 non-null   object
#  7   duration      8787 non-null   object
#  8   listed_in     8787 non-null   object
#  9   Listed 1      8787 non-null   object
#  10  Listed 2      6775 non-null   object
#  11  Listed 3      3725 non-null   object
# dtypes: datetime64[ns](2), object(10)
# memory usage: 892.4+ KB

# %%
df['date_added'] = pd.to_datetime(df['date_added'], format = '%m/%d/%Y', errors = 'coerce')

# %%
df['release_year'] = pd.to_datetime(df['release_year'], format = '%Y', errors = 'coerce')

# %%
# shape, tipos, nulls, duplicados.
def info_gerais(df):
  print(f'QTD Linhas Dataset: {df.shape[0]}')
  print(f'QTD Colunas Dataset: {df.shape[1]}\n')

  for i in df.columns:
    print(f'Coluna {i}\n')
    print(f'QTD Nulos: {df[i].isnull().sum()}')
    print(f'% Nulos: {df[i].isnull().sum()/len(df)}\n')
    print(f'QTD Duplicados: {df[i].duplicated().sum()}\n')
    print(f'Quantidade por categoria: {df[i].value_counts()}\n')
    print(f'Quantidade por categoria: {df[i].value_counts()/len(df)*100}\n')
    print(f'Valores distintos: {df[i].nunique()}\n')

# %%
# Vê todos os títulos duplicados
df[df['title'].duplicated(keep=False)].sort_values('title')
# Out:
#      show_id     type   title            director   country date_added  \
# 2925   s3963    Movie  15-Aug  Swapnaneel Jayakar     India 2019-03-29
# 4261   s5967    Movie  15-Aug  Swapnaneel Jayakar     India 2019-03-29
# 3285   s4523    Movie  22-Jul     Paul Greengrass    Norway 2018-10-10
# 4260   s5966    Movie  22-Jul     Paul Greengrass    Norway 2018-10-10
# 393    s3997  TV Show   9-Feb           Not Given  Pakistan 2019-03-20
# 537    s5965  TV Show   9-Feb           Not Given  Pakistan 2019-03-20
#
#      release_year rating  duration                             listed_in
# 2925   2019-01-01  TV-14   124 min  Comedies, Dramas, Independent Movies
# 4261   2019-01-01  TV-14   124 min  Comedies, Dramas, Independent Movies
# 3285   2018-01-01      R   144 min                     Dramas, Thrillers
# 4260   2018-01-01      R   144 min                     Dramas, Thrillers
# 393    2018-01-01  TV-14  1 Season     International TV Shows, TV Dramas
# ...

# %%
info_gerais(df)
#drop director
#
# Out:
# QTD Linhas Dataset: 8790
# QTD Colunas Dataset: 10
#
# Coluna show_id
#
# QTD Nulos: 0
# % Nulos: 0.0
#
# QTD Duplicados: 0
#
# Quantidade por categoria: show_id
# s8786    1
# s1       1
# s3       1
# s6       1
# s14      1
#         ..
# s941     1
# s940     1
# s13      1
# s939     1
# s10      1
# Name: count, Length: 8790, dtype: int64
#
# Quantidade por categoria: show_id
# s8786    0.011377
# s1       0.011377
# s3       0.011377
# s6       0.011377
# s14      0.011377
#            ...
# s941     0.011377
# s940     0.011377
# s13      0.011377
# s939     0.011377
# s10      0.011377
# Name: count, Length: 8790, dtype: float64
#
# Valores distintos: 8790
#
# Coluna type
#
# QTD Nulos: 0
# % Nulos: 0.0
#
# QTD Duplicados: 8788
#
# Quantidade por categoria: type
# Movie      6126
# TV Show    2664
# Name: count, dtype: int64
#
# Quantidade por categoria: type
# Movie      69.692833
# TV Show    30.307167
# Name: count, dtype: float64
#
# Valores distintos: 2
#
# ...

# %%
df[df['title'].duplicated(keep = False )]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, country, date_added, release_year, rating, duration, listed_in]
# Index: []

# %%
df.drop_duplicates(subset = ['title'], keep= 'last', inplace = True)

# %%
df.drop(columns = ['director'], inplace = True)

# %%
df[['Listed 1', 'Listed 2', 'Listed 3']] = (
    df['listed_in']
    .str.split(',', expand=True)
    .iloc[:, :3]
)

# %%
df['rating'] = df['rating'].replace({'UR': 'NR'})

# %%
df[['Duraçao', 'Métrica']] = df['duration'].str.split(' ', expand = True)

# %%
# replace — só substitui o que está no dicionário, mantém o resto
df['Métrica'] = df['Métrica'].replace({'Seasons': 'Season'})

# %%
display(df)
# Out:
#      show_id     type                             title        country  \
# 0         s1    Movie              Dick Johnson Is Dead  United States
# 1         s3  TV Show                         Ganglands         France
# 2         s6  TV Show                     Midnight Mass  United States
# 3        s14    Movie  Confessions of an Invisible Girl         Brazil
# 4         s8    Movie                           Sankofa  United States
# ...      ...      ...                               ...            ...
# 8785   s8797  TV Show                        Yunus Emre         Turkey
# 8786   s8798  TV Show                         Zak Storm  United States
# 8787   s8801  TV Show                Zindagi Gulzar Hai       Pakistan
# 8788   s8784  TV Show                              Yoko       Pakistan
# 8789   s8786  TV Show                               YOM       Pakistan
#
#      date_added release_year rating   duration  \
# 0    2021-09-25   2020-01-01  PG-13     90 min
# ...

# %%
df.loc[df['date_added'] < df['release_year'], 'date_added'] = None

# %%
df[df['show_id'] == 's5395']
# Out:
#      show_id   type                       title      country date_added  \
# 3869   s5395  Movie  Hans Teeuwen: Real Rancour  Netherlands        NaT
#
#      release_year rating duration        listed_in         Listed 1 Listed 2  \
# 3869   2018-01-01  TV-MA   86 min  Stand-Up Comedy  Stand-Up Comedy     None
#
#      Listed 3
# 3869     None

# %%
df[df['date_added'] < df['release_year']]
# s5395
# s7064
# s7113
# Out:
#      show_id     type                       title         country date_added  \
# 3869   s5395    Movie  Hans Teeuwen: Real Rancour     Netherlands 2017-07-01
# 5138   s7064    Movie                    Incoming          Serbia 2018-10-26
# 5178   s7113  TV Show                 Jack Taylor   United States 2013-03-31
# 6948   s1552  TV Show                       Hilda  United Kingdom 2020-12-14
# 6992   s1697  TV Show                Polly Pocket          Canada 2020-11-15
# 7355   s2921  TV Show               Love Is Blind   United States 2020-02-13
# 7436   s3169  TV Show                Fuller House   United States 2019-12-06
# 7484   s3288  TV Show          Maradona in Mexico       Argentina 2019-11-13
# 7517   s3370  TV Show             BoJack Horseman   United States 2019-10-25
# 7537   s3434  TV Show            The Hook Up Plan          France 2019-10-11
# 7996   s4845  TV Show   Unbreakable Kimmy Schmidt   United States 2018-05-30
# ...
